# %% [markdown]
# <a href="https://colab.research.google.com/github/cperalta22/rconcolab/blob/master/ejercicioClase10paraTodos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tst <- sample(1:10,50,replace = T)
tst
# Out:
#  [1]  5  1  4  2  2  5  5  9  9  6  5  4 10  7  7  2  4  2  3  6  7  4  6  5 10
# [26]  7  3  5  9  8  3  9  3  3  3 10 10  9  3  2  9  5  4  8  6  1  1  7 10  3

# %% [markdown]
# # OBTENER EL PRIMER VALOR DEL VECTOR MAYOR A 8

# %%
masque8 <- tst > 8
tst[masque8] |> head(1)
tst
# Out:
# [1] 10
#  [1]  7  3  3  3  8  4  1  7  7  2 10 10  8 10  3  6 10  2  4  3  4  5 10  7 10
# [26]  4  3  5  9  3  5  2  7  5  7  4  6  8  1  5  5  1  1  1  6  4  6  3  5  8

# %% [markdown]
# ## OBTENER EL INDICE

# %%
tst[tst > 8]
which(tst > 8)
match(TRUE, tst >8)
# Out:
#  [1]  9  9 10 10  9  9 10 10  9  9 10
#  [1]  8  9 13 25 29 32 36 37 38 41 49
# [1] 8

# %%
tst
# Out:
#  [1]  5  1  4  2  2  5  5  9  9  6  5  4 10  7  7  2  4  2  3  6  7  4  6  5 10
# [26]  7  3  5  9  8  3  9  3  3  3 10 10  9  3  2  9  5  4  8  6  1  1  7 10  3

# %%
mayorfor <- c()
for (valor in tst){
 mayorfor <- c(mayorfor, valor > 8)
}

mayor8 <- tst > 8

# %%
mayorfor
mayor8
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE
# [13]  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25]  TRUE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE  TRUE
# [37]  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [49]  TRUE FALSE
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE
# [13]  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25]  TRUE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE  TRUE
# [37]  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [49]  TRUE FALSE

# %%
tst[tst>8][1]
# Out:
# [1] 9
